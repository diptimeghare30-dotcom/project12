# %%
# %sql
USE CATALOG dm_pro2;

# %%
# %sql
CREATE SCHEMA IF NOT EXISTS bronze;
CREATE SCHEMA IF NOT EXISTS silver;
CREATE SCHEMA IF NOT EXISTS gold;

# %%
df=spark.read\
    .format('csv')\
    .option('header','true')\
    .load('abfss://rawdata@dmpro2.dfs.core.windows.net/data/customers')

# df=spark.read\
#     .format('csv')\
#     .option('header','true')\
#     .load('wasbs://rawdata@dm0blob0storage.blob.core.windows.net/employees1.csv')
df.show()
# Out:
# +----------+---------+--------+--------------------+--------+-----------+-----------+-------------+
# |CustomerID|FirstName|LastName|               Email|   Phone|       City|    Country|LoyaltyPoints|
# +----------+---------+--------+--------------------+--------+-----------+-----------+-------------+
# |      C001|     John|     Doe|  john.doe@email.com|555-1234|   New York|        USA|          120|
# |      C002|     Jane|   Smith|jane.smith@email.com|555-5678|Los Angeles|        USA|          200|
# |      C003|      Raj|   Patel| raj.patel@email.com|555-8765|     Mumbai|      India|          150|
# |      C004|    Emily|   Clark|emily.clark@email...|555-4321|     London|         UK|          300|
# |      C005|  Michael|   Brown|michael.brown@ema...|555-2468|    Toronto|     Canada|          180|
# |      C006|   Sophia|   Lopez|sophia.lopez@emai...|555-1357|     Madrid|      Spain|          220|
# |      C007|     Liam|  Wilson|liam.wilson@email...|555-9753|     Sydney|  Australia|           90|
# |      C008|   Olivia|  Martin|olivia.martin@ema...|555-8642|      Paris|     France|          250|
# |      C009|     Noah|     Lee|  noah.lee@email.com|555-7531|      Seoul|South Korea|          175|
# |      C010|      Ava|     Kim|   ava.kim@email.com|555-6420|      Tokyo|      Japan|          210|
# |      C011|    Ethan|  Nguyen|ethan.nguyen@emai...|555-5319|      Hanoi|    Vietnam|           80|
# |      C012|      Mia|    Chen|  mia.chen@email.com|555-4208|    Beijing|      China|          300|
# |      C013|    Lucas|  Garcia|lucas.garcia@emai...|555-3197|Mexico City|     Mexico|          160|
# |      C014| Isabella|   Rossi|isabella.rossi@em...|555-2086|       Rome|      Italy|          190|
# |      C015|   Daniel|Anderson|daniel.anderson@e...|555-1075|    Chicago|        USA|          140|
# |      C016|     Emma|   Scott|emma.scott@email.com|555-9064|  Edinburgh|         UK|          230|
# |      C017|    James|  Walker|james.walker@emai...|555-8053|   Auckland|New Zealand|           95|
# |      C018|Charlotte|   Davis|charlotte.davis@e...|555-7042|     Dublin|    Ireland|          175|
# |      C019|    Henry|   Moore|henry.moore@email...|555-6031|     Berlin|    Germany|          260|
# |      C020|   Amelia|  Taylor|amelia.taylor@ema...|555-5020|  Melbourne|  Australia|          120|
# +----------+---------+--------+--------------------+--------+-----------+-----------+-------------+
# only showing top 20 rows

# %%
storage_account = "dmpro2"
access_key = "blkSylna0g9RsyAQUhzDDyJZ4fS4oWfrveP8HO+FYhp0Y1Cv6hcIGjo2UmS/MWA/TWcTWiAHRTy5+AStQPiZYA=="   # hard-coded

spark.conf.set(f"fs.azure.account.key.{storage_account}.dfs.core.windows.net", access_key)
